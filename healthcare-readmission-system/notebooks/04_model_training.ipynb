# %% [markdown]
# # Phase 5 — Machine Learning
#
# **Target:** Readmitted within 30 days (`readmitted_30_days`)
#
# **Models:** Logistic Regression, Random Forest, XGBoost

# %%
import sys, json
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "backend"))

from app.ml.train import run_training_pipeline

summary = run_training_pipeline()
summary["best_model"], summary["best_test_roc_auc"]

# %%
import pandas as pd

rows = []
for name, res in summary["models"].items():
    m = res["test_metrics"]
    rows.append({
        "model": name,
        "accuracy": m["accuracy"],
        "precision": m["precision"],
        "recall": m["recall"],
        "f1_score": m["f1_score"],
        "roc_auc": m["roc_auc"],
    })

pd.DataFrame(rows).sort_values("roc_auc", ascending=False)
